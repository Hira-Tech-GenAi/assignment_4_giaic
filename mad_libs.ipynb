# %% [markdown]
# <a href="https://colab.research.google.com/github/Hira-Tech-GenAi/assignment_4_giaic/blob/main/mad_libs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎉 Mad Libs Game
#
# Welcome to the **Mad Libs Game**, a fun and interactive Python-based word game! This project lets you fill in the blanks with your own creative words to generate hilarious and unexpected stories.
#
# ## 🧠 What is Mad Libs?
#
# Mad Libs is a word game where players substitute words (like nouns, verbs, adjectives, etc.) into a story template. Once all the blanks are filled, you get a funny and sometimes nonsensical story to enjoy!
#
# ## 🚀 Features
#
# - 📜 Multiple story templates
# - 🎯 Interactive user input
# - 😂 Fun and unexpected results
# - 💻 Beginner-friendly Python code
#
# ## 🛠️ How to Run
#
# 1. Clone or download this repository.
# 2. Open the `mad_libs.ipynb` file in [Google Colab](https://colab.research.google.com) or any Jupyter Notebook environment.
# 3. Run the notebook cells.
# 4. Enter the prompted words.
# 5. Enjoy the story created from your inputs!
#
# ## 📸 Preview
#
# ![mad-libs.jpg](data:image/jpeg;base64,...)

# %%
# 🎉 Welcome to the Emoji Mad Libs Game! 🎉

# 📢 Introduction
print("👋 Hello there! Ready to create a hilarious story? Let's begin! 😄\n")

# 📝 Collecting user inputs with emoji-enhanced prompts
adjective = input("Enter an adjective (e.g., 'funny') 🤔: ")
noun = input("Enter a noun (e.g., 'dog') 🐶: ")
verb = input("Enter a verb (e.g., 'run') 🏃: ")
place = input("Enter a place (e.g., 'beach') 🏖️: ")
adverb = input("Enter an adverb (e.g., 'quickly') 🏎️: ")

# 📖 Story template with placeholders for user inputs
story = f"""
📚 Here's your Mad Libs story:

Today, I went to the {place} 🗺️ and saw a very {adjective} {noun} 🐾.
It decided to {verb} {adverb} 🌀, which was quite unexpected! 😲

The end. 🎬
"""

# 🖨️ Displaying the final story
print(story)
# Out:
# 👋 Hello there! Ready to create a hilarious story? Let's begin! 😄
