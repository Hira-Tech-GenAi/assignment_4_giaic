# %% [markdown]
# <a href="https://colab.research.google.com/github/Hira-Tech-GenAi/assignment_4_giaic/blob/main/countdown_timer_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⏳ Console-Based Countdown Timer – Python Project
#
# Welcome to the **Countdown Timer**, a beginner-friendly Python project that runs directly in the console. It's perfect for learning how to work with loops, user input, and the `time` module. This version works seamlessly in **Google Colab**, terminal, or any Python IDE!
#
# ---
#
# ## 🧠 What is a Countdown Timer?
#
# A countdown timer starts from a specified time and counts down to zero, updating every second. It’s useful in games, productivity apps, and time-based challenges.
#
# ---
#
# ## 🚀 Features
#
# - ⌨️ **User input** for minutes and seconds
# - 🕒 **Real-time countdown** printed to console
# - 🧑‍💻 **No GUI required** – works in any terminal
# - 📚 **Beginner-friendly Python code**
# - 📝 **Clean, commented source code** for learning
#
# ---
#
# ## ▶️ Run in Google Colab
#
# Click the link below to open and run the project in Google Colab:
#
# 👉 [Run in Google Colab](https://colab.research.google.com/drive/1N3FcHTmu53hVuCi04OctlqnlYKDKxXJ0?usp=sharing)
#
#
# ---
#
# ## 🧑‍💻 How to Use
#
# 1. Open the script in your Python environment or Colab
# 2. Enter minutes and seconds when prompted
# 3. Watch the countdown in the console
# 4. When the timer hits 0, you’ll see: **"⏰ Time's up!"**
#
# ---
#
# ![python countdown timer.png](data:image/png;base64,...)

# %%
import time  # Import time module for countdown

# Function to start the countdown
def start_countdown(minutes, seconds):
    # Convert total time to seconds
    total_seconds = minutes * 60 + seconds

    try:
        while total_seconds >= 0:
            # Use divmod to get minutes and seconds
            mins_display, secs_display = divmod(total_seconds, 60)

            # Print countdown in MM:SS format
            print(f"\r⏳ Time Left: {mins_display:02d}:{secs_display:02d}", end="")

            time.sleep(1)  # Wait for 1 second
            total_seconds -= 1  # Decrease time

        print("\n⏰ Time's up!")  # Message when countdown finishes

    except KeyboardInterrupt:
        print("\n❗ Countdown stopped manually.")

# Main function to get input from user
def main():
    print("🎯 Welcome to the Countdown Timer!")

    try:
        # Get minutes and seconds input from user
        mins = int(input("Enter minutes: "))
        secs = int(input("Enter seconds: "))

        # Validate input
        if mins < 0 or secs < 0 or secs >= 60:
            print("⚠️ Please enter valid minutes (>=0) and seconds (0-59).")
            return

        # Start the countdown
        start_countdown(mins, secs)

    except ValueError:
        print("❗ Invalid input! Please enter numbers only.")

# Run the program
if __name__ == "__main__":
    main()
