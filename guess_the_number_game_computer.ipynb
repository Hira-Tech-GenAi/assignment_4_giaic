# %% [markdown]
# <a href="https://colab.research.google.com/github/Hira-Tech-GenAi/assignment_4_giaic/blob/main/guess_the_number_game_computer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Guess the Number (Computer Guesses) 🧠
#
# ## Project Overview
# Welcome to the **Reverse Guess the Number Game**!
# In this project, **you think of a number between 1 and 50**, and the **computer will try to guess it** using your feedback.
#
# ---
#
# ### 🎯 Features:
# - You think of a number between **1 and 50** 🧠
# - The computer makes intelligent guesses using **binary search logic** 📈
# - You give feedback:
#   - `h` = too high 🔺
#   - `l` = too low 🔻
#   - `c` = correct ✅
# - Fast and efficient guessing 🎯
# - Fun and interactive with emoji feedback 🎉
#
# ---
#
# ## 🛠️ How It Works:
# 1. The user thinks of a number between 1 and 50.
# 2. The computer guesses the middle number between the current low and high range.
# 3. The user gives feedback on each guess:
#    - `h` if the guess is too **high**
#    - `l` if the guess is too **low**
#    - `c` if the guess is **correct**
# 4. The computer adjusts its guess based on the feedback until it finds the correct number.
#
# ---![guess-the-number_3.png](data:image/png;base64,...)

# %%
def computer_guess():
    print("🤖 Welcome to the Computer Guess Game!")
    print("🧠 Think of a number between 1 and 50, and I'll try to guess it.")
    input("🎯 Press Enter when you're ready...")

    low = 1
    high = 50
    attempts = 6

    while low <= high:
        guess = (low + high) // 2
        attempts += 1
        print(f"\n🤔 My guess is: {guess}")
        feedback = input("Is it (h)igh, (l)ow, or (c)orrect? ").lower()

        if feedback == 'c':
            print(f"🎉 Yay! I guessed your number in {attempts} attempts!")
            break
        elif feedback == 'h':
            high = guess - 1
        elif feedback == 'l':
            low = guess + 1
        else:
            print("⚠️ Please enter a valid response: 'h', 'l', or 'c'.")

    if low > high:
        print("😕 Hmm, something went wrong. Were you honest about your number?")

computer_guess()
# Out:
# 🤖 Welcome to the Computer Guess Game!
# 🧠 Think of a number between 1 and 50, and I'll try to guess it.
# 🎯 Press Enter when you're ready...
#
# 🤔 My guess is: 25
# Is it (h)igh, (l)ow, or (c)orrect? h
#
# 🤔 My guess is: 12
# Is it (h)igh, (l)ow, or (c)orrect? c
# 🎉 Yay! I guessed your number in 8 attempts!
