# %% [markdown]
# <a href="https://colab.research.google.com/github/Hira-Tech-GenAi/assignment_4_giaic/blob/main/guess_the_number_game_user.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎮 Guess the Number Game 🎮
#
# ## Project Overview
# Welcome to the **Guess the Number Game**! In this project, you'll guess a number between 1 and 50. You have 5 attempts to guess it correctly.
#
# ### Features:
# - Randomly generated number between 1 and 50 🎲
# - 5 attempts to guess the number 🧠
# - Hints on whether your guess is too high or too low 📉📈
# - Fun and interactive with emojis 🎉
#
# ---
#
# ## How It Works:
# 1. The game generates a random number between 1 and 50.
# 2. The user has 5 attempts to guess the number.
# 3. After each guess, the program will tell the user if the guess is:
#    - Too low ⬇️
#    - Too high ⬆️
#    - Correct 🎉
# 4. The user must guess correctly within 5 attempts or the game will reveal the correct number 😞
#
# ![banner (2).png](data:image/png;base64,...)

# %%
import random

def guess_number():
    # Generate a random number between 1 and 50
    number_to_guess = random.randint(1, 50)
    attempts = 5  # Set the number of attempts to 5

    print("🎉 Welcome to the Guess the Number Game! 🎉")
    print("🤔 I'm thinking of a number between 1 and 50. 🤔")
    print("🎯 You have 5 attempts to guess it! 🎯")

    while attempts > 0:
        try:
            # Get user input
            user_guess = int(input(f"\nYou have {attempts} attempts remaining. Enter your guess: "))

            # Check if the guess is within the valid range
            if user_guess < 1 or user_guess > 50:
                print("⚠️ Please guess a number between 1 and 50. ⚠️")
                continue

            # Check if the guess is correct
            if user_guess == number_to_guess:
                print(f"🎉 Congratulations! You guessed the number {number_to_guess} correctly! 🎉")
                break
            elif user_guess < number_to_guess:
                print("⬇️ Too low! Try again. ⬇️")
            else:
                print("⬆️ Too high! Try again. ⬆️")

            # Decrease the number of attempts
            attempts -= 1

        except ValueError:
            print("❌ Invalid input! Please enter a valid number. ❌")

    if attempts == 0:
        print(f"\nSorry! You've used all your attempts. The correct number was {number_to_guess}. 😞")

# Call the function to start the game
guess_number()
# Out:
# 🎉 Welcome to the Guess the Number Game! 🎉
# 🤔 I'm thinking of a number between 1 and 50. 🤔
# 🎯 You have 5 attempts to guess it! 🎯
#
# You have 5 attempts remaining. Enter your guess: 45
# ⬆️ Too high! Try again. ⬆️
#
# You have 4 attempts remaining. Enter your guess: 22
# ⬆️ Too high! Try again. ⬆️
#
# You have 3 attempts remaining. Enter your guess: 12
# ⬇️ Too low! Try again. ⬇️
#
# You have 2 attempts remaining. Enter your guess: 15
# 🎉 Congratulations! You guessed the number 15 correctly! 🎉
