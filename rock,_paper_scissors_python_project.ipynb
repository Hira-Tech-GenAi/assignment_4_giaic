# %% [markdown]
# <a href="https://colab.research.google.com/github/Hira-Tech-GenAi/assignment_4_giaic/blob/main/rock%2C_paper_scissors_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 4: Rock, Paper, Scissors Python Project 🎮
#
# ## Introduction
# Welcome to the **Rock, Paper, Scissors** game built in Python! This fun and interactive command-line game lets you compete against the computer. With colorful emojis (✊📄✂️), the game is engaging and easy to play. The project is designed to run seamlessly in **Google Colab**, making it accessible without local setup. 🚀
#
# This markdown file provides an overview of the project, including how to set it up, play the game, and understand the code. Let's dive in! 😄
#
# ## Requirements
# - **Python 3.x** (pre-installed in Google Colab)
# - **random** module (part of Python's standard library)
# - No additional libraries are needed! 🎉
# - Run the game in Google Colab for the best experience.
#
# ## How to Play
# 1. Run the code in Google Colab.
# 2. The game will display a welcome message and the rules:
#    - ✊ Rock smashes ✂️ Scissors
#    - 📄 Paper covers ✊ Rock
#    - ✂️ Scissors cuts 📄 Paper
# 3. Enter your choice by typing:
#    - `1` for ✊ Rock
#    - `2` for 📄 Paper
#    - `3` for ✂️ Scissors
# 4. The computer randomly selects its choice.
# 5. The game shows both choices and declares the winner:
#    - 🏆 You win if your choice beats the computer's.
#    - 😞 Computer wins if its choice beats yours.
#    - 🤝 It's a tie if both choices are the same.
# 6. Choose to play again (`y`) or exit (`n`). 👋
#
# ## Setup in Google Colab
# 1. Open [Google Colab](https://colab.research.google.com).
# 2. Create a new notebook.
# 3. Copy and paste the Python code from `rock_paper_scissors.py` into a code cell.
# 4. Run the cell by clicking the play button or pressing `Shift + Enter`.
# 5. Follow the prompts to play the game! 🕹️
#
# ## Code Explanation
# The Python code is simple and beginner-friendly. Here's a breakdown:
#
# - **Imports**: The `random` module is used to generate the computer's choice.
# - **Function**: The `play_game()` function contains the game logic.
# - **Choices**: A dictionary maps user inputs (`1`, `2`, `3`) to choices with emojis (`✊ Rock`, `📄 Paper`, `✂️ Scissors`).
# - **Game Loop**:
#   - Prompts the user for input and validates it.
#   - Randomly selects the computer's choice.
#   - Displays both choices and determines the winner based on the rules.
#   - Asks if the user wants to play again.
# - **Emojis**: Used to represent choices and enhance the user experience (e.g., 🏆 for winning, 🤝 for a tie).
#
# ## Example Output![spock-paper-scissors.png](data:image/png;base64,...)

# %%
import random

def play_game():
    print("🎮 Welcome to Rock, Paper, Scissors! 🎉")
    print("Winning rules: ✊ Rock smashes ✂️ Scissors, 📄 Paper covers ✊ Rock, ✂️ Scissors cuts 📄 Paper")

    choices = {"1": "✊ Rock", "2": "📄 Paper", "3": "✂️ Scissors"}

    while True:
        print("\nEnter your choice:")
        print("1 - ✊ Rock")
        print("2 - 📄 Paper")
        print("3 - ✂️ Scissors")

        user_choice = input("Your choice (1-3): ").strip()

        if user_choice not in ["1", "2", "3"]:
            print("❌ Invalid choice! Please enter 1, 2, or 3.")
            continue

        user_action = choices[user_choice]
        computer_action = random.choice(list(choices.values()))

        print(f"\nYou chose: {user_action}")
        print(f"Computer chose: {computer_action}")

        if user_action == computer_action:
            print("🤝 It's a tie!")
        elif (user_action == "✊ Rock" and computer_action == "✂️ Scissors") or \
             (user_action == "📄 Paper" and computer_action == "✊ Rock") or \
             (user_action == "✂️ Scissors" and computer_action == "📄 Paper"):
            print("🏆 You win!")
        else:
            print("😞 Computer wins!")

        play_again = input("\nPlay again? (y/n): ").lower()
        if play_again != "y":
            print("👋 Thanks for playing!")


play_game()
# Out:
# 🎮 Welcome to Rock, Paper, Scissors! 🎉
# Winning rules: ✊ Rock smashes ✂️ Scissors, 📄 Paper covers ✊ Rock, ✂️ Scissors cuts 📄 Paper
#
# Enter your choice:
# 1 - ✊ Rock
# 2 - 📄 Paper
# 3 - ✂️ Scissors
# Your choice (1-3): 2
#
# You chose: 📄 Paper
# Computer chose: 📄 Paper
# 🤝 It's a tie!
#
# Play again? (y/n): y
#
# Enter your choice:
# 1 - ✊ Rock
# 2 - 📄 Paper
# 3 - ✂️ Scissors
# Your choice (1-3): 1
#
# You chose: ✊ Rock
# Computer chose: ✂️ Scissors
# 🏆 You win!
